# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def estimate_coef(x,y):
    n = np.size(x)
    m_x = np.mean(x)
    m_y = np.mean(y)
    SS_xy = (np.sum(y*x)) - (n*m_y*m_x)
    SS_xx = (np.sum(x*x)) - (n*m_x*m_x)
    b_1 = SS_xy / SS_xx
    b_0 = m_y - b_1*m_x
    return (b_0, b_1)

# %%
def plot_regression_line(x,y,b):
    plt.scatter(x,y,color='red',marker='o',s=30)
    y_pred = b[0] + b[1]*x
    plt.plot(x,y_pred,color="green")
    plt.xlabel("x")
    plt.ylabel("y")

# %%
def main():
    x = np.array([25,67,72,74,18,34,78,35,47,93,71,6,9,77,41,19,4,73,100,32])
    y = np.array([58,66,15,49,29,87,18,10,47,61,99,70,91,53,86,22,20,74,32,80])

    b = estimate_coef(x,y)
    print("Estimated Coefficients :\n b_0 = {} \n b_1 = {}".format(b[0],b[1]))
    plot_regression_line(x,y,b)

# %%
main()
# Out:
# Estimated Coefficients :
#  b_0 = 55.557211255050255
#  b_1 = -0.045276128308723095
